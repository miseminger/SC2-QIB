# %% [markdown]
# The purpose of this notebook is to make an annotated phylogenetic tree plot based on `210717.lebanon.table_tree.html`, using 75 sequences from Norwich and surrounding England.
#
# tree: `/home/ubuntu/20220228/timetree-madeline/mugration/annotated_tree.nexus`
# confidence: `/home/ubuntu/20220228/timetree-madeline/mugration/confidence.csv`
# metadata: `/home/ubuntu/20220228/treetime_dates_30.tsv`

# %%
library(phangorn)
library(ggtreeExtra)
library(ggtree)
library(ggnewscale)
library(colorspace);
library(RColorBrewer);
library(dplyr)
library(tidyr)
library(ggplot2)
library(ggpubr)
library(stringr)
library(castor)
library(lubridate)
library(ramify)
library(ape)

# %%
tree <- "../data/mugration_plot/annotated_tree.nexus"
confidence <- "../data/mugration_plot/confidence.csv"
metadata <- "../data/mugration_plot/treetime_dates_30.tsv"
gtr <- "../data/mugration_plot/GTR.txt"
pango <- "../data/mugration_plot/lineage_report.csv"
cog_uk_meta <- "../cog_global_2022-02-06_public.csv.xz"

# %%
tre0 <- read.nexus(tree) #timetree mugration output
tbl00 <- read.csv(metadata,sep="\t")
tbl0 <- read.csv("../peroba_meta.220209_173253.tsv.xz", sep="\t")
tbl1 <- read.csv(confidence)

# %%
head(tbl0,3)
# Out:
#   strain                              gisaid_id       date
# 1 Albania/CO-00602-XXK000_1740_3/2021 EPI_ISL_9237997 2021-12-03
# 2 Albania/CO-00602-XXK000_1787_3/2021 EPI_ISL_9237972 2021-12-06
# 3 Albania/CO-00602-XXK000_1950_3/2021 EPI_ISL_9238008 2021-12-13
#   location                   location_gisaid        location_coguk age gender
# 1 Europe / Albania / Tropoje Europe/Albania/Tropoje NA             85  Male
# 2 Europe / Albania / Krume   Europe/Albania/Krume   NA             ?   Male
# 3 Europe / Albania / Tropoje Europe/Albania/Tropoje NA             72  Female
#   gisaid_clade pango_lineage timestamp freq_ACGT freq_N seq_hash
# 1 GK           AY.4          220210.1  27971     1932   9f91794c
# 2 GK           AY.43         220210.1  29557      346   ec4ce6c5
# 3 GK           AY.46         220210.1  29170      733   d3a175e0

# %%
cog <- read.csv(cog_uk_meta, sep=",")
head(cog,3)
# Out:
#   sequence_name             is_uk is_cog_uk central_sample_id
# 1 England/DHSC-CYBYPPC/2022 Y     Y         DHSC-CYBYPPC
# 2 England/DHSC-CYBW4HZ/2022 Y     Y         DHSC-CYBW4HZ
# 3 England/DHSC-CYDRSK9/2022 Y     Y         DHSC-CYDRSK9
#   secondary_identifier sample_date epi_week country adm1   is_surveillance
# 1 NA                   2022-01-31  110      UK      UK-ENG N
# 2 NA                   2022-01-31  110      UK      UK-ENG N
# 3 NA                   2022-01-31  110      UK      UK-ENG N
#   is_travel_history travel_history lineage uk_lineage del_lineage
# 1 NA                               BA.1.1  UK25900    del_trans_46464
# 2 NA                               BA.1.1  UK28289    del_trans_72650
# 3 NA                               BA.1.1  UK25785    del_trans_33377
#   phylotype
# 1 UK25900_1
# 2 UK28289_1.2.1
# 3 UK25785_1

# %%
treetips <- str_replace(tre0$tip.label, "_", "/")
cog <- cog[ cog$sequence_name %in% treetips,] #subset the big .xz file by your leaf tips

# %%
head(cog,3)
# Out:
#      sequence_name is_uk is_cog_uk central_sample_id secondary_identifier
#      sample_date epi_week country adm1 is_surveillance is_travel_history
#      travel_history lineage uk_lineage del_lineage phylotype

# %% [markdown]
# Make a dataframe with the sample names and the GTR letter code with the highest likelihood for each:

# %%
df <- data.frame(tbl1)
Node <- as.character(df[,'X.name'])

df$X.name <- NULL
Letter <- colnames(df)[max.col(df,ties.method="first")]

dataset1 <- as.data.frame(cbind(Node, Letter))

# %% [markdown]
# Map the 4-letter region codes to this dataframe:
#
#   K: ?
#   A: ALDP
#   B: HSLL
#   C: LOND
#   D: LSPA
#   E: MILK
#   F: NORW
#   G: PHEC
#   H: PHWC
#   I: PLYM
#   J: QEUH

# %%
Region <- c("ALDP", "HSLL", "LOND", "LSPA", "MILK", "NORW", "PHEC", "PHWC", "PLYM", "QEUH", "?")
Letter <- c("A", "B", "C", "D", "E", "F", "G", "H", "I", "J", "K")

dict <- data.frame(Letter, Region)

total <- merge(dict,dataset1,by="Letter")

total
# Out:
#    Letter Region Node
# 1  A      ALDP   England_ALDP-308C434_2021
# 2  A      ALDP   England_ALDP-30BB6CD_2021
# 3  A      ALDP   England_ALDP-2FE62BA_2021
# 4  A      ALDP   England_ALDP-30910ED_2021
# 5  A      ALDP   England_ALDP-308716F_2021
# 6  B      HSLL   England_HSLL-3411A10_2022
# 7  C      LOND   England_LOND-YYBNE1Q_2022
# 8  D      LSPA   England_LSPA-3096F18_2021
# 9  E      MILK   England_MILK-307D409_2021
# 10 E      MILK   England_MILK-3128D5C_2022
# 11 F      NORW   NODE_0000013
# 12 F      NORW   NODE_0000003
# 13 F      NORW   England_NORW-310B1DB_2021
# 14 F      NORW   England_NORW-3131603_2021
# 15 F      NORW   NODE_0000000
# 16 F      NORW   NODE_0000005
# 17 F      NORW   England_NORW-310A81F_2021
# 18 F      NORW   NODE_0000004
# 19 F      NORW   NODE_0000012
# 20 F      NORW   NODE_0000001
# 21 F      NORW   England_NORW-3134059_2021
# 22 F      NORW   NODE_0000023
# 23 F      NORW   England_NORW-310CD87_2021
# 24 F      NORW   NODE_0000016
# 25 F      NORW   NODE_0000002
# 26 F      NORW   England_NORW-310AC61_2021
# 27 F      NORW   England_NORW-3130981_2021
# 28 F      NORW   England_NORW-310AF34_2021
# 29 F      NORW   England_NORW-3106C6A_2021
# 30 F      NORW   NODE_0000027
# 31 F      NORW   England_NORW-310A207_2021
# 32 F      NORW   England_NORW-31325C9_2021
# 33 F      NORW   England_NORW-3121DE0_2021
# 34 F      NORW   NODE_0000011
# 35 F      NORW   England_NORW-310B970_2021
# 36 F      NORW   England_NORW-310A900_2021
# 37 F      NORW   NODE_0000018
# 38 G      PHEC   England_PHEC-3V068VA5_2021
# 39 G      PHEC   England_PHEC-YYB3M8U_2021
# 40 G      PHEC   England_PHEC-3V0B1V3C_2021
# 41 G      PHEC   NODE_0000006
# 42 H      PHWC   England_PHWC-PGUS16_2021
# 43 I      PLYM   England_PLYM-2FD8154_2021
# 44 J      QEUH   England_QEUH-329870D_2022

# %%
tbl0$strain <- gsub('/', '_', tbl0$strain) #replace / with _ in strain column to match the leaf tips
#head(tbl0$strain, 4)

tbl0 <- tbl0[ tbl0$strain %in% tre0$tip.label,] #subset the big peroba.xz file by your leaf tips
tbl0 <- tbl0 %>% separate(col="location_gisaid",into=c("Continent","Country","Province"),sep="/")
tbl0[tbl0==""] <- NA  ## empty Continent, Country become NA
#Leo has more lines to let you choose between location and gisaid_location contents
tbl0 <- tbl0 %>% select (strain,date,Continent,Country,Province,gender,age) #keep just the useful columns
# Out:
# Error in `stop_subscript()`:
# ! Can't extract columns that don't exist.
# ✖ Column `location_gisaid` doesn't exist.
# Traceback:
#
# 1. tbl0 %>% separate(col = "location_gisaid", into = c("Continent",
#  .     "Country", "Province"), sep = "/")
# 2. separate(., col = "location_gisaid", into = c("Continent", "Country",
#  .     "Province"), sep = "/")
# 3. separate.data.frame(., col = "location_gisaid", into = c("Continent",
#  .     "Country", "Province"), sep = "/")
# 4. tidyselect::vars_pull(names(data), !!enquo(col))
# 5. pull_as_location2(loc, n, vars)
# 6. with_subscript_errors(type = "pull", {
#  .     i <- vctrs::vec_as_subscript2(i, arg = "var", logical = "error")
#  .     if (is.numeric(i)) {
#  .         vctrs::num_as_location2(i, n = n, negative = "ignore",
#  .             arg = "var")
#  .     }
#  .     else {
#  .         vctrs::vec_as_location2(i, n = n, names = names, arg = "var")
#  .     }
#  . })
# 7. tryCatch(with_entraced_errors(expr), vctrs_error_subscript = function(cnd) {
#  .     cnd$subscript_action <- subscript_action(type)
#  .     cnd$subscript_elt <- "column"
#  .     cnd_signal(cnd)
#  . })
# 8. tryCatchList(expr, classes, parentenv, handlers)
# 9. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 10. value[[3L]](cond)
# 11. cnd_signal(cnd)
# 12. signal_abort(cnd)

# %%
#add pangolin strains

tbl2 <- read.csv (pango)
tbl2 <- tbl2 %>% select (taxon,lineage) %>% rename (strain=taxon)
cat("dim tbl2 (pangolin lineage report) formated= ", dim(tbl2)); head(tbl2,3)

tbl0 <- merge (tbl0, tbl2)

cat("Lineages from NORW in order of frequency: ")
x1 <- tbl0[tbl0["Region"]=="NORW",]
sort(table(x1["lineage"]), decreasing=TRUE)

cat("Lineages from !NORW in order of frequency: ")
x1 <- tbl0[!tbl0["Region"]=="NORW",]
sort(table(x1["lineage"]), decreasing=TRUE)
# Out:
# dim tbl2 (pangolin lineage report) formated=  30 2
#   strain                    lineage
# 1 England_ALDP-2FE62BA_2021 B.1
# 2 England_ALDP-30BB6CD_2021 B.1
# 3 England_LSPA-3096F18_2021 B.1
# Lineages from NORW in order of frequency:
#   B.1 B.1.1
#    13     1
# Lineages from !NORW in order of frequency:
# B.1
#  16

# %%
tbl0$shortdate <- substring(tbl0$date,1,7)
tbl0$Region <- substring(tbl0$strain,9,12)
tbl0[tbl0=="?"] <- NA

# merge rows with same strain  https://stackoverflow.com/a/14283757/204903
suppressWarnings( tbl0 <- aggregate(x=tbl0[,!colnames(tbl0) %in% "strain"], by=list(strain=tbl0$strain), min, na.rm=TRUE) )

# 10 England  NA     NA  2022-01   MILK   global
# 11 England  NA     NA  2021-12   NORW   exposure
# 12 England  NA     NA  2021-12   NORW   exposure
# 13 England  NA     NA  2021-12   NORW   exposure
# 14 England  NA     NA  2021-12   NORW   exposure
# 15 England  NA     NA  2021-12   NORW   exposure
# 16 England  NA     NA  2021-12   NORW   exposure
# 17 England  NA     NA  2021-12   NORW   exposure
# 18 England  NA     NA  2021-12   NORW   exposure
# 19 England  NA     NA  2021-12   NORW   exposure
# 20 England  NA     NA  2021-12   NORW   exposure
# 21 England  NA     NA  2021-12   NORW   exposure
# 22 England  NA     NA  2021-12   NORW   exposure
# 23 England  NA     NA  2021-12   NORW   exposure
# 24 England  NA     NA  2021-12   NORW   exposure
# 25 England  NA     NA  2021-12   PHEC   global
# 26 England  NA     NA  2021-12   PHEC   global
# 27 England  NA     NA  2021-12   PHEC   global
# 28 England  NA     NA  2021-12   PHWC   global
# 29 England  NA     NA  2021-12   PLYM   global
# 30 England  NA     NA  2022-01   QEUH   global

# %% [markdown]
# I don't have access to travel history yet, so for the sake of the tree I'll make it up.  Pretend every sample was taken in Norwich and the codes represent the travel history instead.

# %%
tbl0$local <- "global"
tbl0[tbl0["Region"]=="NORW","local"] <- "exposure"

# %%
#make a new df with the strains as rownames
traits <- tbl0 %>% slice(match(tre0$tip.label, strain))
rownames(traits) <- traits$strain
traits
# Out:
#                            strain                     lineage date
# England_NORW-3131603_2021  England_NORW-3131603_2021  B.1.1   2021-12-30
# England_PHEC-3V068VA5_2021 England_PHEC-3V068VA5_2021 B.1     2021-12-05
# England_LOND-YYBNE1Q_2022  England_LOND-YYBNE1Q_2022  B.1     2022-01-03
# England_NORW-310B1DB_2021  England_NORW-310B1DB_2021  B.1     2021-12-18
# England_MILK-3128D5C_2022  England_MILK-3128D5C_2022  B.1     2022-01-05
# England_MILK-307D409_2021  England_MILK-307D409_2021  B.1     2021-12-30
# England_PHEC-3V0B1V3C_2021 England_PHEC-3V0B1V3C_2021 B.1     2021-12-08
# England_NORW-310A81F_2021  England_NORW-310A81F_2021  B.1     2021-12-24
# England_NORW-3130981_2021  England_NORW-3130981_2021  B.1     2021-12-29
# England_LSPA-3096F18_2021  England_LSPA-3096F18_2021  B.1     2021-12-28
# England_PHEC-YYB3M8U_2021  England_PHEC-YYB3M8U_2021  B.1     2021-12-27
# England_NORW-31325C9_2021  England_NORW-31325C9_2021  B.1     2021-12-28
# England_HSLL-3411A10_2022  England_HSLL-3411A10_2022  B.1     2022-01-23
# England_NORW-310CD87_2021  England_NORW-310CD87_2021  B.1     2021-12-22
# England_ALDP-2FE62BA_2021  England_ALDP-2FE62BA_2021  B.1     2021-12-24
# England_PLYM-2FD8154_2021  England_PLYM-2FD8154_2021  B.1     2021-12-23
# England_ALDP-308C434_2021  England_ALDP-308C434_2021  B.1     2021-12-24
# England_NORW-310AF34_2021  England_NORW-310AF34_2021  B.1     2021-12-25
# England_NORW-3106C6A_2021  England_NORW-3106C6A_2021  B.1     2021-12-24
# England_NORW-3131603_2021  2021-12   NORW   exposure
# England_PHEC-3V068VA5_2021 2021-12   PHEC   global
# England_LOND-YYBNE1Q_2022  2022-01   LOND   global
# England_NORW-310B1DB_2021  2021-12   NORW   exposure
# England_MILK-3128D5C_2022  2022-01   MILK   global
# England_MILK-307D409_2021  2021-12   MILK   global
# England_PHEC-3V0B1V3C_2021 2021-12   PHEC   global
# England_NORW-310A81F_2021  2021-12   NORW   exposure
# England_NORW-3130981_2021  2021-12   NORW   exposure
# England_LSPA-3096F18_2021  2021-12   LSPA   global
# England_PHEC-YYB3M8U_2021  2021-12   PHEC   global
# England_NORW-31325C9_2021  2021-12   NORW   exposure
# England_HSLL-3411A10_2022  2022-01   HSLL   global
# England_NORW-310CD87_2021  2021-12   NORW   exposure
# England_ALDP-2FE62BA_2021  2021-12   ALDP   global
# England_PLYM-2FD8154_2021  2021-12   PLYM   global
# England_ALDP-308C434_2021  2021-12   ALDP   global
# England_NORW-310AF34_2021  2021-12   NORW   exposure
# England_NORW-3106C6A_2021  2021-12   NORW   exposure
# England_NORW-3134059_2021  2021-12   NORW   exposure
# England_ALDP-30BB6CD_2021  2021-12   ALDP   global
# England_NORW-3121DE0_2021  2021-12   NORW   exposure
# England_NORW-310A207_2021  2021-12   NORW   exposure
# England_NORW-310B970_2021  2021-12   NORW   exposure
# England_ALDP-308716F_2021  2021-12   ALDP   global
# England_NORW-310AC61_2021  2021-12   NORW   exposure
# England_PHWC-PGUS16_2021   2021-12   PHWC   global
# England_NORW-310A900_2021  2021-12   NORW   exposure
# England_QEUH-329870D_2022  2022-01   QEUH   global
# England_ALDP-30910ED_2021  2021-12   ALDP   global

# %% [markdown]
# Exposure Plot

# %%
groupInfo <- split (tre0$tip.label, traits["local"]); 
groupInfo <- groupInfo[c("qib","exposure","global")]  ## last is "ancestral state", when colouring edges (however colors etc. follow alphabetical order)
grouptre <- groupOTU(tre0, groupInfo, group_name="group1")  #ok, probably this is where it merges

# %%
groupInfo #a list
# Out:
# $<NA>
# NULL
#
# $exposure
#  [1] "England_NORW-3131603_2021" "England_NORW-310B1DB_2021"
#  [3] "England_NORW-310A81F_2021" "England_NORW-3130981_2021"
#  [5] "England_NORW-31325C9_2021" "England_NORW-310CD87_2021"
#  [7] "England_NORW-310AF34_2021" "England_NORW-3106C6A_2021"
#  [9] "England_NORW-3134059_2021" "England_NORW-3121DE0_2021"
# [11] "England_NORW-310A207_2021" "England_NORW-310B970_2021"
# [13] "England_NORW-310AC61_2021" "England_NORW-310A900_2021"
#
# $global
#  [1] "England_PHEC-3V068VA5_2021" "England_LOND-YYBNE1Q_2022"
#  [3] "England_MILK-3128D5C_2022"  "England_MILK-307D409_2021"
#  [5] "England_PHEC-3V0B1V3C_2021" "England_LSPA-3096F18_2021"
#  [7] "England_PHEC-YYB3M8U_2021"  "England_HSLL-3411A10_2022"
#  [9] "England_ALDP-2FE62BA_2021"  "England_PLYM-2FD8154_2021"
# [11] "England_ALDP-308C434_2021"  "England_ALDP-30BB6CD_2021"
# [13] "England_ALDP-308716F_2021"  "England_PHWC-PGUS16_2021"
# [15] "England_QEUH-329870D_2022"  "England_ALDP-30910ED_2021"

# %%
grouptre
# Out:
# Phylogenetic tree with 30 tips and 14 internal nodes.
#
# Tip labels:
#   England_NORW-3131603_2021, England_PHEC-3V068VA5_2021, England_LOND-YYBNE1Q_2022, England_NORW-310B1DB_2021, England_MILK-3128D5C_2022, England_MILK-307D409_2021, ...
# Node labels:
#   NODE_0000004, NODE_0000005, NODE_0000006, NODE_0000003, NODE_0000011, NODE_0000012, ...
#
# Rooted; includes branch lengths.

# %%
tre0$node.label
# Out:
#  [1] "NODE_0000004" "NODE_0000005" "NODE_0000006" "NODE_0000003" "NODE_0000011"
#  [6] "NODE_0000012" "NODE_0000013" "NODE_0000001" "NODE_0000002" "NODE_0000000"
# [11] "NODE_0000023" "NODE_0000027" "NODE_0000016" "NODE_0000018"

# %%
class(tre0)
# Out:
# [1] "phylo"

# %%
#general plot options for trees

options(repr.plot.width=26, repr.plot.height=20) ; par(oma=c(0,0,0,0)) 
getPal_country = colorRampPalette( c(brewer.pal(12,"Set3"),brewer.pal(8,"Set1")) )(length(unique(traits$Country)))
getPal_lineage = colorRampPalette( brewer.pal(8,"Dark2"))(length(unique(traits$lineage)))  ## RdYlGn Set2
getPal_local   = c("tomato4","gray60","cadetblue4")
getPal_continent = colorRampPalette( brewer.pal(10,"BrBG"))(5)
getPal_region = colorRampPalette( c(brewer.pal(12,"Set3"),brewer.pal(8,"Set1")) )(length(unique(traits$region)))

#p <- ggtree (grouptre,  aes(color=group1),size=0.4, layout="rectangular") %<+% traits
p <- ggtree (grouptre,  aes(color=group1),size=0.4, layout="fan", open.angle=5) # ,  mrsd="2021-07-12", as.Date = T)  ## most recent date
p
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# plot without title

# %%
#now do one for Pango

groupInfo2 <- split (tre0$tip.label, traits["lineage"]); 
grouptre2 <- groupOTU(tre0, groupInfo2, group_name="group2")  #ok, probably this is where it merges

#p <- ggtree (grouptre,  aes(color=group1),size=0.4, layout="rectangular") %<+% traits
p <- ggtree (grouptre2,  aes(color=group2),size=0.4, layout="fan", open.angle=5) # ,  mrsd="2021-07-12", as.Date = T)  ## most recent date
p
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# plot without title

# %% [markdown]
# Combine the nodes and tips into a single dataframe, like `traits`.

# %%
names(total)[names(total) == 'Node'] <- 'strain' #rename

nodes <- total[ total$strain %in% tre0$node.label,]
nodes$Letter <- NULL
cols_to_add <- setdiff(names(traits), names(nodes))
nodes[ , cols_to_add] <- NA

nodes$local <- "global"
nodes[nodes["Region"]=="NORW","local"] <- "exposure"

rownames(nodes) <- nodes$strain

both <- rbind(nodes, traits)

both
# Out:
#                            Region strain                     lineage date
# NODE_0000013               NORW   NODE_0000013               NA      NA
# NODE_0000003               NORW   NODE_0000003               NA      NA
# NODE_0000000               NORW   NODE_0000000               NA      NA
# NODE_0000005               NORW   NODE_0000005               NA      NA
# NODE_0000004               NORW   NODE_0000004               NA      NA
# England_NORW-310A900_2021  NORW   England_NORW-310A900_2021  B.1     2021-12-28
# England_QEUH-329870D_2022  QEUH   England_QEUH-329870D_2022  B.1     2022-01-10
# England_ALDP-30910ED_2021  ALDP   England_ALDP-30910ED_2021  B.1     2021-12-30
#                            Continent Country        Province gender age
# NODE_0000013               NA        NA             NA       NA     NA
# NODE_0000003               NA        NA             NA       NA     NA
# NODE_0000000               NA        NA             NA       NA     NA
# NODE_0000005               NA        NA             NA       NA     NA
# NODE_0000004               NA        NA             NA       NA     NA
# NODE_0000012               NA        NA             NA       NA     NA
# NODE_0000001               NA        NA             NA       NA     NA
# NODE_0000023               NA        NA             NA       NA     NA
# NODE_0000016               NA        NA             NA       NA     NA
# NODE_0000002               NA        NA             NA       NA     NA
# NODE_0000027               NA        NA             NA       NA     NA
# NODE_0000011               NA        NA             NA       NA     NA
# NODE_0000018               NA        NA             NA       NA     NA
# NODE_0000006               NA        NA             NA       NA     NA
# England_NORW-3131603_2021  Europe    United Kingdom England  NA     NA
# England_PHEC-3V068VA5_2021 Europe    United Kingdom England  NA     NA
# England_LOND-YYBNE1Q_2022  Europe    United Kingdom England  NA     NA
# England_NORW-310B1DB_2021  Europe    United Kingdom England  NA     NA
# England_MILK-3128D5C_2022  Europe    United Kingdom England  NA     NA
# England_MILK-307D409_2021  Europe    United Kingdom England  NA     NA
# England_PHEC-3V0B1V3C_2021 Europe    United Kingdom England  NA     NA
# England_NORW-310A81F_2021  Europe    United Kingdom England  NA     NA
# England_NORW-3130981_2021  Europe    United Kingdom England  NA     NA
# England_LSPA-3096F18_2021  Europe    United Kingdom England  NA     NA
# England_PHEC-YYB3M8U_2021  Europe    United Kingdom England  NA     NA
# England_NORW-31325C9_2021  Europe    United Kingdom England  NA     NA
# England_HSLL-3411A10_2022  Europe    United Kingdom England  NA     NA
# England_NORW-310CD87_2021  Europe    United Kingdom England  NA     NA
# England_ALDP-2FE62BA_2021  Europe    United Kingdom England  NA     NA
# England_PLYM-2FD8154_2021  Europe    United Kingdom England  NA     NA
# England_ALDP-308C434_2021  Europe    United Kingdom England  NA     NA
# England_NORW-310AF34_2021  Europe    United Kingdom England  NA     NA
# England_NORW-3106C6A_2021  Europe    United Kingdom England  NA     NA
# England_NORW-3134059_2021  Europe    United Kingdom England  NA     NA
# England_ALDP-30BB6CD_2021  Europe    United Kingdom England  NA     NA
# England_NORW-3121DE0_2021  Europe    United Kingdom England  NA     NA
# England_NORW-310A207_2021  Europe    United Kingdom England  NA     NA
# England_NORW-310B970_2021  Europe    United Kingdom England  NA     NA
# England_ALDP-308716F_2021  Europe    United Kingdom England  NA     NA
# England_NORW-310AC61_2021  Europe    United Kingdom England  NA     NA
# England_PHWC-PGUS16_2021   Europe    United Kingdom England  NA     NA
# England_NORW-310A900_2021  Europe    United Kingdom England  NA     NA
# England_QEUH-329870D_2022  Europe    United Kingdom England  NA     NA
# England_ALDP-30910ED_2021  Europe    United Kingdom England  NA     NA
#                            shortdate local
# NODE_0000013               NA        exposure
# NODE_0000003               NA        exposure
# NODE_0000000               NA        exposure
# NODE_0000005               NA        exposure
# NODE_0000004               NA        exposure
# NODE_0000012               NA        exposure
# NODE_0000001               NA        exposure
# NODE_0000023               NA        exposure
# NODE_0000016               NA        exposure
# NODE_0000002               NA        exposure
# NODE_0000027               NA        exposure
# NODE_0000011               NA        exposure
# NODE_0000018               NA        exposure
# NODE_0000006               NA        global
# England_NORW-3131603_2021  2021-12   exposure
# England_PHEC-3V068VA5_2021 2021-12   global
# England_LOND-YYBNE1Q_2022  2022-01   global
# England_NORW-310B1DB_2021  2021-12   exposure
# England_MILK-3128D5C_2022  2022-01   global
# England_MILK-307D409_2021  2021-12   global
# England_PHEC-3V0B1V3C_2021 2021-12   global
# England_NORW-310A81F_2021  2021-12   exposure
# England_NORW-3130981_2021  2021-12   exposure
# England_LSPA-3096F18_2021  2021-12   global
# England_PHEC-YYB3M8U_2021  2021-12   global
# England_NORW-31325C9_2021  2021-12   exposure
# England_HSLL-3411A10_2022  2022-01   global
# England_NORW-310CD87_2021  2021-12   exposure
# England_ALDP-2FE62BA_2021  2021-12   global
# England_PLYM-2FD8154_2021  2021-12   global
# England_ALDP-308C434_2021  2021-12   global
# England_NORW-310AF34_2021  2021-12   exposure
# England_NORW-3106C6A_2021  2021-12   exposure
# England_NORW-3134059_2021  2021-12   exposure
# England_ALDP-30BB6CD_2021  2021-12   global
# England_NORW-3121DE0_2021  2021-12   exposure
# England_NORW-310A207_2021  2021-12   exposure
# England_NORW-310B970_2021  2021-12   exposure
# England_ALDP-308716F_2021  2021-12   global
# England_NORW-310AC61_2021  2021-12   exposure
# England_PHWC-PGUS16_2021   2021-12   global
# England_NORW-310A900_2021  2021-12   exposure
# England_QEUH-329870D_2022  2022-01   global
# England_ALDP-30910ED_2021  2021-12   global

# %%
groupInfo <- split (c(tre0$tip.label, tre0$node.label), traits["local"]); 
groupInfo <- groupInfo[c("qib","exposure","global")]  ## last is "ancestral state", when colouring edges (however colors etc. follow alphabetical order)
grouptre3 <- groupOTU(tre0, groupInfo, group_name="group3")  #ok, probably this is where it merges

#p <- ggtree (grouptre,  aes(color=group1),size=0.4, layout="rectangular") %<+% traits
p <- ggtree (grouptre3,  aes(color=group3),size=0.4, layout="fan", open.angle=5) # ,  mrsd="2021-07-12", as.Date = T)  ## most recent date
p
# Out:
# Warning message in split.default(c(tre0$tip.label, tre0$node.label), traits["local"]):
# “data length is not a multiple of split variable”
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# plot without title

# %%
groupInfo <- split (tre0$tip.label, traits["local"]); 
groupInfo <- groupInfo[c("qib","exposure","global")]  ## last is "ancestral state", when colouring edges (however colors etc. follow alphabetical order)
grouptre3 <- groupOTU(tre0, groupInfo, group_name="group3")  #ok, probably this is where it merges

#p <- ggtree (grouptre,  aes(color=group1),size=0.4, layout="rectangular") %<+% traits
p <- ggtree (grouptre3,  aes(color=group3),size=0.4, layout="fan", open.angle=5) # ,  mrsd="2021-07-12", as.Date = T)  ## most recent date
p
# Out:
# Scale for 'y' is already present. Adding another scale for 'y', which will
# replace the existing scale.
# plot without title
